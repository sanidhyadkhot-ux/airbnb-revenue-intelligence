# %% [markdown]
# # Airbnb Revenue Intelligence - EDA
# This notebook supports the SQL + Streamlit project.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/airbnb_wa_clean.csv')
df.head()

# %%
df[['price_clean','review_scores_rating','availability_365','estimated_annual_revenue']].describe()
